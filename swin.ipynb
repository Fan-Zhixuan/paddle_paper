# %%
import numpy as np

import paddle
import paddle.nn as nn
import paddle.vision.transforms as T

from ppim.models.vit import Mlp
from ppim.models.common import to_2tuple
from ppim.models.common import DropPath, Identity
from ppim.models.common import trunc_normal_, zeros_, ones_

# %%
def window_partition(x, window_size):
    """
    Args:
        x: (B, H, W, C)
        window_size (int): window size
    Returns:
        windows: (num_windows*B, window_size, window_size, C)
    """
    B, H, W, C = x.shape
    x = x.reshape((B, H // window_size, window_size,
                   W // window_size, window_size, C))
    windows = x.transpose((0, 1, 3, 2, 4, 5)).reshape(
        (-1, window_size, window_size, C))
    return windows


def window_reverse(windows, window_size, H, W):
    """
    Args:
        windows: (num_windows*B, window_size, window_size, C)
        window_size (int): Window size
        H (int): Height of image
        W (int): Width of image
    Returns:
        x: (B, H, W, C)
    """
    B = int(windows.shape[0] / (H * W / window_size / window_size))
    x = windows.reshape(
        (B, H // window_size, W // window_size, window_size, window_size, -1))
    x = x.transpose((0, 1, 3, 2, 4, 5)).reshape((B, H, W, -1))
    return x


class WindowAttention(nn.Layer):
    r""" Window based multi-head self attention (W-MSA) module with relative position bias.
    It supports both of shifted and non-shifted window.
    Args:
        dim (int): Number of input channels.
        window_size (tuple[int]): The height and width of the window.
        num_heads (int): Number of attention heads.
        qkv_bias (bool, optional):  If True, add a learnable bias to query, key, value. Default: True
        qk_scale (float | None, optional): Override default qk scale of head_dim ** -0.5 if set
        attn_drop (float, optional): Dropout ratio of attention weight. Default: 0.0
        proj_drop (float, optional): Dropout ratio of output. Default: 0.0
    """

    def __init__(self, dim, window_size, num_heads, qkv_bias=True, qk_scale=None, attn_drop=0., proj_drop=0.):

        super().__init__()
        self.dim = dim
        self.window_size = window_size  # Wh, Ww
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = qk_scale or head_dim ** -0.5

        # define a parameter table of relative position bias
        self.relative_position_bias_table = self.create_parameter(
            shape=((2 * window_size[0] - 1) *
                   (2 * window_size[1] - 1), num_heads),
            default_initializer=zeros_
        )  # 2*Wh-1 * 2*Ww-1, nH
        self.add_parameter("relative_position_bias_table",
                           self.relative_position_bias_table)

        # get pair-wise relative position index for each token inside the window
        coords_h = paddle.arange(self.window_size[0])
        coords_w = paddle.arange(self.window_size[1])
        coords = paddle.stack(paddle.meshgrid(
            [coords_h, coords_w]))  # 2, Wh, Ww
        coords_flatten = paddle.flatten(coords, 1)  # 2, Wh*Ww
        relative_coords = coords_flatten.unsqueeze(-1) - \
            coords_flatten.unsqueeze(1)  # 2, Wh*Ww, Wh*Ww
        relative_coords = relative_coords.transpose(
            (1, 2, 0))  # Wh*Ww, Wh*Ww, 2
        relative_coords[:, :, 0] += self.window_size[0] - \
            1  # shift to start from 0
        relative_coords[:, :, 1] += self.window_size[1] - 1
        relative_coords[:, :, 0] *= 2 * self.window_size[1] - 1

        relative_position_index = relative_coords.sum(-1)  # Wh*Ww, Wh*Ww
        self.register_buffer("relative_position_index",
                             relative_position_index)

        self.qkv = nn.Linear(dim, dim * 3, bias_attr=qkv_bias)
        self.attn_drop = nn.Dropout(attn_drop)
        self.proj = nn.Linear(dim, dim)
        self.proj_drop = nn.Dropout(proj_drop)

        trunc_normal_(self.relative_position_bias_table)
        self.softmax = nn.Softmax(axis=-1)

    def forward(self, x, mask=None):
        """
        Args:
            x: input features with shape of (num_windows*B, N, C)
            mask: (0/-inf) mask with shape of (num_windows, Wh*Ww, Wh*Ww) or None
        """
        B_, N, C = x.shape
        qkv = self.qkv(x).reshape((B_, N, 3, self.num_heads, C //
                                   self.num_heads)).transpose((2, 0, 3, 1, 4))
        q, k, v = qkv[0], qkv[1], qkv[2]

        q = q * self.scale
        attn = q.matmul(k.transpose((0, 1, 3, 2)))

        relative_position_bias = paddle.index_select(
            self.relative_position_bias_table,
            self.relative_position_index.reshape((-1,)),
            axis=0).reshape(
            (self.window_size[0] * self.window_size[1],
             self.window_size[0] * self.window_size[1], -1))
        relative_position_bias = relative_position_bias.transpose((2, 0, 1))

        attn = attn + relative_position_bias.unsqueeze(0)

        if mask is not None:
            nW = mask.shape[0]
            attn = attn.reshape(
                (B_ // nW, nW, self.num_heads, N, N)
            ) + mask.unsqueeze(1).unsqueeze(0)
            attn = attn.reshape((-1, self.num_heads, N, N))
            attn = self.softmax(attn)
        else:
            attn = self.softmax(attn)

        attn = self.attn_drop(attn)

        x = (attn.matmul(v)).transpose((0, 2, 1, 3)).reshape((B_, N, C))
        x = self.proj(x)
        x = self.proj_drop(x)
        return x


class SwinTransformerBlock(nn.Layer):
    r""" Swin Transformer Block.
    Args:
        dim (int): Number of input channels.
        input_resolution (tuple[int]): Input resulotion.
        num_heads (int): Number of attention heads.
        window_size (int): Window size.
        shift_size (int): Shift size for SW-MSA.
        mlp_ratio (float): Ratio of mlp hidden dim to embedding dim.
        qkv_bias (bool, optional): If True, add a learnable bias to query, key, value. Default: True
        qk_scale (float | None, optional): Override default qk scale of head_dim ** -0.5 if set.
        drop (float, optional): Dropout rate. Default: 0.0
        attn_drop (float, optional): Attention dropout rate. Default: 0.0
        drop_path (float, optional): Stochastic depth rate. Default: 0.0
        act_layer (nn.Layer, optional): Activation layer. Default: nn.GELU
        norm_layer (nn.Layer, optional): Normalization layer.  Default: nn.LayerNorm
    """

    def __init__(self, dim, input_resolution, num_heads, window_size=7, shift_size=0,
                 mlp_ratio=4., qkv_bias=True, qk_scale=None, drop=0., attn_drop=0., drop_path=0.,
                 act_layer=nn.GELU, norm_layer=nn.LayerNorm):
        super().__init__()
        self.dim = dim
        self.input_resolution = input_resolution
        self.num_heads = num_heads
        self.window_size = window_size
        self.shift_size = shift_size
        self.mlp_ratio = mlp_ratio
        if min(self.input_resolution) <= self.window_size:
            # if window size is larger than input resolution, we don't partition windows
            self.shift_size = 0
            self.window_size = min(self.input_resolution)
        assert 0 <= self.shift_size < self.window_size, "shift_size must in 0-window_size"

        self.norm1 = norm_layer(dim)
        self.attn = WindowAttention(
            dim, window_size=to_2tuple(self.window_size), num_heads=num_heads,
            qkv_bias=qkv_bias, qk_scale=qk_scale, attn_drop=attn_drop, proj_drop=drop)

        self.drop_path = DropPath(drop_path) if drop_path > 0. else Identity()
        self.norm2 = norm_layer(dim)
        mlp_hidden_dim = int(dim * mlp_ratio)
        self.mlp = Mlp(in_features=dim, hidden_features=mlp_hidden_dim,
                       act_layer=act_layer, drop=drop)

        if self.shift_size > 0:
            # calculate attention mask for SW-MSA
            H, W = self.input_resolution
            img_mask = paddle.zeros((1, H, W, 1))  # 1 H W 1

            h_slices = (slice(0, -self.window_size),
                        slice(-self.window_size, -self.shift_size),
                        slice(-self.shift_size, None))
            w_slices = (slice(0, -self.window_size),
                        slice(-self.window_size, -self.shift_size),
                        slice(-self.shift_size, None))
            cnt = 0
            for h in h_slices:
                for w in w_slices:
                    img_mask[:, h, w, :] = cnt
                    cnt += 1

            # nW, window_size, window_size, 1
            mask_windows = window_partition(img_mask, self.window_size)
            mask_windows = mask_windows.reshape((-1,
                                                 self.window_size * self.window_size))
            attn_mask = mask_windows.unsqueeze(1) - mask_windows.unsqueeze(2)

            _h = paddle.full_like(attn_mask, -100.0, dtype='float32')
            _z = paddle.full_like(attn_mask, 0.0, dtype='float32')
            attn_mask = paddle.where(attn_mask != 0, _h, _z)

        else:
            attn_mask = None

        self.register_buffer("attn_mask", attn_mask)

    def forward(self, x):
        H, W = self.input_resolution
        B, L, C = x.shape
        assert L == H * W, "input feature has wrong size"

        shortcut = x
        x = self.norm1(x)
        x = x.reshape((B, H, W, C))

        # cyclic shift
        if self.shift_size > 0:
            shifted_x = paddle.roll(
                x, shifts=(-self.shift_size, -self.shift_size), axis=(1, 2))
        else:
            shifted_x = x

        # partition windows
        # nW*B, window_size, window_size, C
        x_windows = window_partition(shifted_x, self.window_size)
        # nW*B, window_size*window_size, C
        x_windows = x_windows.reshape(
            (-1, self.window_size * self.window_size, C))

        # W-MSA/SW-MSA
        # nW*B, window_size*window_size, C
        attn_windows = self.attn(x_windows, mask=self.attn_mask)

        # merge windows
        attn_windows = attn_windows.reshape(
            (-1, self.window_size, self.window_size, C))
        shifted_x = window_reverse(
            attn_windows, self.window_size, H, W)  # B H' W' C

        # reverse cyclic shift
        if self.shift_size > 0:
            x = paddle.roll(shifted_x, shifts=(
                self.shift_size, self.shift_size), axis=(1, 2))
        else:
            x = shifted_x
        x = x.reshape((B, H * W, C))

        # FFN
        x = shortcut + self.drop_path(x)
        x = x + self.drop_path(self.mlp(self.norm2(x)))

        return x


class PatchMerging(nn.Layer):
    r""" Patch Merging Layer.
    Args:
        input_resolution (tuple[int]): Resolution of input feature.
        dim (int): Number of input channels.
        norm_layer (nn.Layer, optional): Normalization layer.  Default: nn.LayerNorm
    """

    def __init__(self, input_resolution, dim, norm_layer=nn.LayerNorm):
        super().__init__()
        self.input_resolution = input_resolution
        self.dim = dim
        self.reduction = nn.Linear(4 * dim, 2 * dim, bias_attr=False)
        self.norm = norm_layer(4 * dim)

    def forward(self, x):
        """
        x: B, H*W, C
        """
        H, W = self.input_resolution
        B, L, C = x.shape
        assert L == H * W, "input feature has wrong size"
        assert H % 2 == 0 and W % 2 == 0, f"x size ({H}*{W}) are not even."

        x = x.reshape((B, H, W, C))

        x0 = x[:, 0::2, 0::2, :]  # B H/2 W/2 C
        x1 = x[:, 1::2, 0::2, :]  # B H/2 W/2 C
        x2 = x[:, 0::2, 1::2, :]  # B H/2 W/2 C
        x3 = x[:, 1::2, 1::2, :]  # B H/2 W/2 C
        x = paddle.concat([x0, x1, x2, x3], -1)  # B H/2 W/2 4*C
        x = x.reshape((B, -1, 4 * C))  # B H/2*W/2 4*C

        x = self.norm(x)
        x = self.reduction(x)

        return x


class BasicLayer(nn.Layer):
    """ A basic Swin Transformer layer for one stage.
    Args:
        dim (int): Number of input channels.
        input_resolution (tuple[int]): Input resolution.
        depth (int): Number of blocks.
        num_heads (int): Number of attention heads.
        window_size (int): Local window size.
        mlp_ratio (float): Ratio of mlp hidden dim to embedding dim.
        qkv_bias (bool, optional): If True, add a learnable bias to query, key, value. Default: True
        qk_scale (float | None, optional): Override default qk scale of head_dim ** -0.5 if set.
        drop (float, optional): Dropout rate. Default: 0.0
        attn_drop (float, optional): Attention dropout rate. Default: 0.0
        drop_path (float | tuple[float], optional): Stochastic depth rate. Default: 0.0
        norm_layer (nn.Layer, optional): Normalization layer. Default: nn.LayerNorm
        downsample (nn.Layer | None, optional): Downsample layer at the end of the layer. Default: None
    """

    def __init__(self, dim, input_resolution, depth, num_heads, window_size,
                 mlp_ratio=4., qkv_bias=True, qk_scale=None, drop=0., attn_drop=0.,
                 drop_path=0., norm_layer=nn.LayerNorm, downsample=None):

        super().__init__()
        self.dim = dim
        self.input_resolution = input_resolution
        self.depth = depth
        # build blocks
        self.blocks = nn.LayerList([
            SwinTransformerBlock(dim=dim, input_resolution=input_resolution,
                                 num_heads=num_heads, window_size=window_size,
                                 shift_size=0 if (
                                     i % 2 == 0) else window_size // 2,
                                 mlp_ratio=mlp_ratio,
                                 qkv_bias=qkv_bias, qk_scale=qk_scale,
                                 drop=drop, attn_drop=attn_drop,
                                 drop_path=drop_path[i] if isinstance(
                                     drop_path, np.ndarray) else drop_path,
                                 norm_layer=norm_layer)
            for i in range(depth)])

        # patch merging layer
        if downsample is not None:
            self.downsample = downsample(
                input_resolution, dim=dim, norm_layer=norm_layer)
        else:
            self.downsample = None

    def forward(self, x):
        for blk in self.blocks:
            x = blk(x)
        if self.downsample is not None:
            x = self.downsample(x)
        return x


class PatchEmbed(nn.Layer):
    r""" Image to Patch Embedding
    Args:
        img_size (int): Image size.  Default: 224.
        patch_size (int): Patch token size. Default: 4.
        in_chans (int): Number of input image channels. Default: 3.
        embed_dim (int): Number of linear projection output channels. Default: 96.
        norm_layer (nn.Layer, optional): Normalization layer. Default: None
    """

    def __init__(self, img_size=224, patch_size=4, in_chans=3, embed_dim=96, norm_layer=None):
        super().__init__()
        img_size = to_2tuple(img_size)
        patch_size = to_2tuple(patch_size)
        patches_resolution = [img_size[0] //
                              patch_size[0], img_size[1] // patch_size[1]]
        self.img_size = img_size
        self.patch_size = patch_size
        self.patches_resolution = patches_resolution
        self.num_patches = patches_resolution[0] * patches_resolution[1]

        self.in_chans = in_chans
        self.embed_dim = embed_dim

        self.proj = nn.Conv2D(in_chans, embed_dim,
                              kernel_size=patch_size, stride=patch_size)
        if norm_layer is not None:
            self.norm = norm_layer(embed_dim)
        else:
            self.norm = None

    def forward(self, x):
        B, C, H, W = x.shape
        # FIXME look at relaxing size constraints
        assert H == self.img_size[0] and W == self.img_size[1], \
            f"Input image size ({H}*{W}) doesn't match model ({self.img_size[0]}*{self.img_size[1]})."
        x = self.proj(x).flatten(2).transpose((0, 2, 1))  # B Ph*Pw C
        if self.norm is not None:
            x = self.norm(x)
        return x


class SwinTransformer(nn.Layer):
    r""" Swin Transformer
        A Paddle impl of : `Swin Transformer: Hierarchical Vision Transformer using Shifted Windows`  -
          https://arxiv.org/pdf/2103.14030
    Args:
        img_size (int | tuple(int)): Input image size. Default 224
        patch_size (int | tuple(int)): Patch size. Default: 4
        in_chans (int): Number of input image channels. Default: 3
        class_dim (int): Number of classes for classification head. Default: 1000
        embed_dim (int): Patch embedding dimension. Default: 96
        depths (tuple(int)): Depth of each Swin Transformer layer.
        num_heads (tuple(int)): Number of attention heads in different layers.
        window_size (int): Window size. Default: 7
        mlp_ratio (float): Ratio of mlp hidden dim to embedding dim. Default: 4
        qkv_bias (bool): If True, add a learnable bias to query, key, value. Default: True
        qk_scale (float): Override default qk scale of head_dim ** -0.5 if set. Default: None
        drop_rate (float): Dropout rate. Default: 0
        attn_drop_rate (float): Attention dropout rate. Default: 0
        drop_path_rate (float): Stochastic depth rate. Default: 0.1
        norm_layer (nn.Layer): Normalization layer. Default: nn.LayerNorm.
        ape (bool): If True, add absolute position embedding to the patch embedding. Default: False
        patch_norm (bool): If True, add normalization after patch embedding. Default: True
    """

    def __init__(self, img_size=224, patch_size=4, in_chans=3,
                 embed_dim=96, depths=[2, 2, 6, 2], num_heads=[3, 6, 12, 24],
                 window_size=7, mlp_ratio=4., qkv_bias=True, qk_scale=None,
                 drop_rate=0., attn_drop_rate=0., drop_path_rate=0.1,
                 norm_layer=nn.LayerNorm, ape=False, patch_norm=True,
                 class_dim=1000, with_pool=True, **kwargs):
        super().__init__()
        self.class_dim = class_dim
        self.with_pool = with_pool

        self.num_layers = len(depths)
        self.embed_dim = embed_dim
        self.ape = ape
        self.patch_norm = patch_norm
        self.num_features = int(embed_dim * 2 ** (self.num_layers - 1))
        self.mlp_ratio = mlp_ratio

        # split image into non-overlapping patches
        self.patch_embed = PatchEmbed(
            img_size=img_size, patch_size=patch_size, in_chans=in_chans, embed_dim=embed_dim,
            norm_layer=norm_layer if self.patch_norm else None)
        num_patches = self.patch_embed.num_patches
        patches_resolution = self.patch_embed.patches_resolution
        self.patches_resolution = patches_resolution

        # absolute position embedding
        if self.ape:
            self.absolute_pos_embed = self.create_parameter(
                shape=(1, num_patches, embed_dim),
                default_initializer=zeros_
            )
            self.add_parameter("absolute_pos_embed", self.absolute_pos_embed)
            trunc_normal_(self.absolute_pos_embed)

        self.pos_drop = nn.Dropout(p=drop_rate)

        # stochastic depth
        dpr = np.linspace(0, drop_path_rate, sum(depths))

        # build layers
        self.layers = nn.LayerList()
        for i_layer in range(self.num_layers):
            layer = BasicLayer(dim=int(embed_dim * 2 ** i_layer),
                               input_resolution=(patches_resolution[0] // (2 ** i_layer),
                                                 patches_resolution[1] // (2 ** i_layer)),
                               depth=depths[i_layer],
                               num_heads=num_heads[i_layer],
                               window_size=window_size,
                               mlp_ratio=self.mlp_ratio,
                               qkv_bias=qkv_bias, qk_scale=qk_scale,
                               drop=drop_rate, attn_drop=attn_drop_rate,
                               drop_path=dpr[sum(depths[:i_layer]):sum(
                                   depths[:i_layer + 1])],
                               norm_layer=norm_layer,
                               downsample=PatchMerging if (
                                   i_layer < self.num_layers - 1) else None
                               )
            self.layers.append(layer)

        self.norm = norm_layer(self.num_features)

        if with_pool:
            self.avgpool = nn.AdaptiveAvgPool1D(1)
        
        if class_dim > 0:
            self.head = nn.Linear(self.num_features, class_dim)

        self.apply(self._init_weights)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            trunc_normal_(m.weight)
            if isinstance(m, nn.Linear) and m.bias is not None:
                zeros_(m.bias)
        elif isinstance(m, nn.LayerNorm):
            zeros_(m.bias)
            ones_(m.weight)

    def forward_features(self, x):
        x = self.patch_embed(x)
        if self.ape:
            x = x + self.absolute_pos_embed
        x = self.pos_drop(x)
        print(x.shape)
        # for layer in self.layers:
        #     x = layer(x)
        x = self.layers[0](x)

        x = self.layers[1](x)
 
        x = self.layers[2](x)
   
        x = self.layers[3](x)
    

        x = self.norm(x)  # B L C
        return x.transpose((0, 2, 1)) # B C 1

    def forward(self, x):
        x = self.forward_features(x)

        if self.with_pool:
            x = self.avgpool(x) 

        if self.class_dim > 0:
            x = paddle.flatten(x, 1)
            x = self.head(x)

        return x

# %%
def swin_tiny_window7_224(**kwargs):
    model = SwinTransformer(img_size = 224,
                            embed_dim = 96,
                            depths = [ 2, 2, 6, 2 ],
                            num_heads = [ 3, 6, 12, 24 ],
                            window_size = 7,
                            drop_path_rate=0.2,
                            **kwargs)
    return model

def swin_small_window7_224(**kwargs):
    model = SwinTransformer(img_size = 224,
                            embed_dim = 96,
                            depths = [ 2, 2, 18, 2 ],
                            num_heads = [ 3, 6, 12, 24 ],
                            window_size = 7,
                            drop_path_rate=0.3,
                            **kwargs)
    return model

def swin_base_window7_224(**kwargs):
    model = SwinTransformer(img_size = 224,
                            embed_dim = 128,
                            depths = [ 2, 2, 18, 2 ],
                            num_heads = [ 4, 8, 16, 32 ],
                            window_size = 7,
                            drop_path_rate=0.5,
                            **kwargs)
    return model

def swin_large_window7_224(**kwargs):
    model = SwinTransformer(img_size = 224,
                            embed_dim = 192,
                            depths = [ 2, 2, 18, 2 ],
                            num_heads = [ 6, 12, 24, 48 ],
                            window_size = 7,
                            **kwargs)
    return model

def swin_base_window12_384(**kwargs):
    model = SwinTransformer(img_size = 384,
                            embed_dim = 128,
                            depths = [ 2, 2, 18, 2 ],
                            num_heads = [ 4, 8, 16, 32 ],
                            window_size = 12,
                            **kwargs)
    return model

def swin_large_window12_384(**kwargs):
    model = SwinTransformer(img_size = 384,
                            embed_dim = 192,
                            depths = [ 2, 2, 18, 2 ],
                            num_heads = [ 6, 12, 24, 48 ],
                            window_size = 12,
                            **kwargs)
    return model

# %%
model = swin_tiny_window7_224(class_dim = 10)
model = paddle.Model(model)
model.summary((1,3,224,224))
# Out:
# [1, 3136, 96]
# [1, 784, 192]
# [1, 196, 384]
# [1, 49, 768]
# [1, 49, 768]
# -----------------------------------------------------------------------------------
#      Layer (type)           Input Shape          Output Shape         Param #
# ===================================================================================
#        Conv2D-2          [[1, 3, 224, 224]]    [1, 96, 56, 56]         4,704
#      LayerNorm-30         [[1, 3136, 96]]       [1, 3136, 96]           192
#      PatchEmbed-2        [[1, 3, 224, 224]]     [1, 3136, 96]            0
#       Dropout-38          [[1, 3136, 96]]       [1, 3136, 96]            0
#      LayerNorm-31         [[1, 3136, 96]]       [1, 3136, 96]           192
#        Linear-53           [[64, 49, 96]]       [64, 49, 288]         27,936
#       Softmax-13         [[64, 3, 49, 49]]     [64, 3, 49, 49]           0
#       Dropout-39         [[64, 3, 49, 49]]     [64, 3, 49, 49]           0
#        Linear-54           [[64, 49, 96]]        [64, 49, 96]          9,312
#       Dropout-40           [[64, 49, 96]]        [64, 49, 96]            0
#   WindowAttention-13       [[64, 49, 96]]        [64, 49, 96]           507
#       Identity-2          [[1, 3136, 96]]       [1, 3136, 96]            0
#      LayerNorm-32         [[1, 3136, 96]]       [1, 3136, 96]           192
#        Linear-55          [[1, 3136, 96]]       [1, 3136, 384]        37,248
#         GELU-13           [[1, 3136, 384]]      [1, 3136, 384]           0
#       Dropout-41          [[1, 3136, 96]]       [1, 3136, 96]            0
#        Linear-56          [[1, 3136, 384]]      [1, 3136, 96]         36,960
#         Mlp-13            [[1, 3136, 96]]       [1, 3136, 96]            0
# SwinTransformerBlock-13   [[1, 3136, 96]]       [1, 3136, 96]            0
#      LayerNorm-33         [[1, 3136, 96]]       [1, 3136, 96]           192
#        Linear-57           [[64, 49, 96]]       [64, 49, 288]         27,936
#       Softmax-14         [[64, 3, 49, 49]]     [64, 3, 49, 49]           0
#       Dropout-42         [[64, 3, 49, 49]]     [64, 3, 49, 49]           0
#        Linear-58           [[64, 49, 96]]        [64, 49, 96]          9,312
#       Dropout-43           [[64, 49, 96]]        [64, 49, 96]            0
#   WindowAttention-14       [[64, 49, 96]]        [64, 49, 96]           507
#       DropPath-12         [[1, 3136, 96]]       [1, 3136, 96]            0
#      LayerNorm-34         [[1, 3136, 96]]       [1, 3136, 96]           192
#        Linear-59          [[1, 3136, 96]]       [1, 3136, 384]        37,248
#         GELU-14           [[1, 3136, 384]]      [1, 3136, 384]           0
#       Dropout-44          [[1, 3136, 96]]       [1, 3136, 96]            0
#        Linear-60          [[1, 3136, 384]]      [1, 3136, 96]         36,960
#         Mlp-14            [[1, 3136, 96]]       [1, 3136, 96]            0
# SwinTransformerBlock-14   [[1, 3136, 96]]       [1, 3136, 96]            0
#      LayerNorm-35         [[1, 784, 384]]       [1, 784, 384]           768
#        Linear-61          [[1, 784, 384]]       [1, 784, 192]         73,728
#     PatchMerging-4        [[1, 3136, 96]]       [1, 784, 192]            0
#      BasicLayer-5         [[1, 3136, 96]]       [1, 784, 192]            0
#      LayerNorm-36         [[1, 784, 192]]       [1, 784, 192]           384
#        Linear-62          [[16, 49, 192]]       [16, 49, 576]         111,168
#       Softmax-15         [[16, 6, 49, 49]]     [16, 6, 49, 49]           0
#       Dropout-45         [[16, 6, 49, 49]]     [16, 6, 49, 49]           0
#        Linear-63          [[16, 49, 192]]       [16, 49, 192]         37,056
#       Dropout-46          [[16, 49, 192]]       [16, 49, 192]            0
#   WindowAttention-15      [[16, 49, 192]]       [16, 49, 192]          1,014
#       DropPath-13         [[1, 784, 192]]       [1, 784, 192]            0
#      LayerNorm-37         [[1, 784, 192]]       [1, 784, 192]           384
#        Linear-64          [[1, 784, 192]]       [1, 784, 768]         148,224
#         GELU-15           [[1, 784, 768]]       [1, 784, 768]            0
#       Dropout-47          [[1, 784, 192]]       [1, 784, 192]            0
#        Linear-65          [[1, 784, 768]]       [1, 784, 192]         147,648
#         Mlp-15            [[1, 784, 192]]       [1, 784, 192]            0
# SwinTransformerBlock-15   [[1, 784, 192]]       [1, 784, 192]            0
#      LayerNorm-38         [[1, 784, 192]]       [1, 784, 192]           384
#        Linear-66          [[16, 49, 192]]       [16, 49, 576]         111,168
#       Softmax-16         [[16, 6, 49, 49]]     [16, 6, 49, 49]           0
#       Dropout-48         [[16, 6, 49, 49]]     [16, 6, 49, 49]           0
#        Linear-67          [[16, 49, 192]]       [16, 49, 192]         37,056
#       Dropout-49          [[16, 49, 192]]       [16, 49, 192]            0
#   WindowAttention-16      [[16, 49, 192]]       [16, 49, 192]          1,014
#       DropPath-14         [[1, 784, 192]]       [1, 784, 192]            0
#      LayerNorm-39         [[1, 784, 192]]       [1, 784, 192]           384
#        Linear-68          [[1, 784, 192]]       [1, 784, 768]         148,224
#         GELU-16           [[1, 784, 768]]       [1, 784, 768]            0
#       Dropout-50          [[1, 784, 192]]       [1, 784, 192]            0
#        Linear-69          [[1, 784, 768]]       [1, 784, 192]         147,648
#         Mlp-16            [[1, 784, 192]]       [1, 784, 192]            0
# SwinTransformerBlock-16   [[1, 784, 192]]       [1, 784, 192]            0
#      LayerNorm-40         [[1, 196, 768]]       [1, 196, 768]          1,536
#        Linear-70          [[1, 196, 768]]       [1, 196, 384]         294,912
#     PatchMerging-5        [[1, 784, 192]]       [1, 196, 384]            0
#      BasicLayer-6         [[1, 784, 192]]       [1, 196, 384]            0
#      LayerNorm-41         [[1, 196, 384]]       [1, 196, 384]           768
#        Linear-71           [[4, 49, 384]]       [4, 49, 1152]         443,520
#       Softmax-17         [[4, 12, 49, 49]]     [4, 12, 49, 49]           0
#       Dropout-51         [[4, 12, 49, 49]]     [4, 12, 49, 49]           0
#        Linear-72           [[4, 49, 384]]        [4, 49, 384]         147,840
#       Dropout-52           [[4, 49, 384]]        [4, 49, 384]            0
#   WindowAttention-17       [[4, 49, 384]]        [4, 49, 384]          2,028
#       DropPath-15         [[1, 196, 384]]       [1, 196, 384]            0
#      LayerNorm-42         [[1, 196, 384]]       [1, 196, 384]           768
#        Linear-73          [[1, 196, 384]]       [1, 196, 1536]        591,360
#         GELU-17           [[1, 196, 1536]]      [1, 196, 1536]           0
#       Dropout-53          [[1, 196, 384]]       [1, 196, 384]            0
#        Linear-74          [[1, 196, 1536]]      [1, 196, 384]         590,208
#         Mlp-17            [[1, 196, 384]]       [1, 196, 384]            0
# SwinTransformerBlock-17   [[1, 196, 384]]       [1, 196, 384]            0
#      LayerNorm-43         [[1, 196, 384]]       [1, 196, 384]           768
#        Linear-75           [[4, 49, 384]]       [4, 49, 1152]         443,520
#       Softmax-18         [[4, 12, 49, 49]]     [4, 12, 49, 49]           0
#       Dropout-54         [[4, 12, 49, 49]]     [4, 12, 49, 49]           0
#        Linear-76           [[4, 49, 384]]        [4, 49, 384]         147,840
#       Dropout-55           [[4, 49, 384]]        [4, 49, 384]            0
#   WindowAttention-18       [[4, 49, 384]]        [4, 49, 384]          2,028
#       DropPath-16         [[1, 196, 384]]       [1, 196, 384]            0
#      LayerNorm-44         [[1, 196, 384]]       [1, 196, 384]           768
#        Linear-77          [[1, 196, 384]]       [1, 196, 1536]        591,360
#         GELU-18           [[1, 196, 1536]]      [1, 196, 1536]           0
#       Dropout-56          [[1, 196, 384]]       [1, 196, 384]            0
#        Linear-78          [[1, 196, 1536]]      [1, 196, 384]         590,208
#         Mlp-18            [[1, 196, 384]]       [1, 196, 384]            0
# SwinTransformerBlock-18   [[1, 196, 384]]       [1, 196, 384]            0
#      LayerNorm-45         [[1, 196, 384]]       [1, 196, 384]           768
#        Linear-79           [[4, 49, 384]]       [4, 49, 1152]         443,520
#       Softmax-19         [[4, 12, 49, 49]]     [4, 12, 49, 49]           0
#       Dropout-57         [[4, 12, 49, 49]]     [4, 12, 49, 49]           0
#        Linear-80           [[4, 49, 384]]        [4, 49, 384]         147,840
#       Dropout-58           [[4, 49, 384]]        [4, 49, 384]            0
#   WindowAttention-19       [[4, 49, 384]]        [4, 49, 384]          2,028
#       DropPath-17         [[1, 196, 384]]       [1, 196, 384]            0
#      LayerNorm-46         [[1, 196, 384]]       [1, 196, 384]           768
#        Linear-81          [[1, 196, 384]]       [1, 196, 1536]        591,360
#         GELU-19           [[1, 196, 1536]]      [1, 196, 1536]           0
#       Dropout-59          [[1, 196, 384]]       [1, 196, 384]            0
#        Linear-82          [[1, 196, 1536]]      [1, 196, 384]         590,208
#         Mlp-19            [[1, 196, 384]]       [1, 196, 384]            0
# SwinTransformerBlock-19   [[1, 196, 384]]       [1, 196, 384]            0
#      LayerNorm-47         [[1, 196, 384]]       [1, 196, 384]           768
#        Linear-83           [[4, 49, 384]]       [4, 49, 1152]         443,520
#       Softmax-20         [[4, 12, 49, 49]]     [4, 12, 49, 49]           0
#       Dropout-60         [[4, 12, 49, 49]]     [4, 12, 49, 49]           0
#        Linear-84           [[4, 49, 384]]        [4, 49, 384]         147,840
#       Dropout-61           [[4, 49, 384]]        [4, 49, 384]            0
#   WindowAttention-20       [[4, 49, 384]]        [4, 49, 384]          2,028
#       DropPath-18         [[1, 196, 384]]       [1, 196, 384]            0
#      LayerNorm-48         [[1, 196, 384]]       [1, 196, 384]           768
#        Linear-85          [[1, 196, 384]]       [1, 196, 1536]        591,360
#         GELU-20           [[1, 196, 1536]]      [1, 196, 1536]           0
#       Dropout-62          [[1, 196, 384]]       [1, 196, 384]            0
#        Linear-86          [[1, 196, 1536]]      [1, 196, 384]         590,208
#         Mlp-20            [[1, 196, 384]]       [1, 196, 384]            0
# SwinTransformerBlock-20   [[1, 196, 384]]       [1, 196, 384]            0
#      LayerNorm-49         [[1, 196, 384]]       [1, 196, 384]           768
#        Linear-87           [[4, 49, 384]]       [4, 49, 1152]         443,520
#       Softmax-21         [[4, 12, 49, 49]]     [4, 12, 49, 49]           0
#       Dropout-63         [[4, 12, 49, 49]]     [4, 12, 49, 49]           0
#        Linear-88           [[4, 49, 384]]        [4, 49, 384]         147,840
#       Dropout-64           [[4, 49, 384]]        [4, 49, 384]            0
#   WindowAttention-21       [[4, 49, 384]]        [4, 49, 384]          2,028
#       DropPath-19         [[1, 196, 384]]       [1, 196, 384]            0
#      LayerNorm-50         [[1, 196, 384]]       [1, 196, 384]           768
#        Linear-89          [[1, 196, 384]]       [1, 196, 1536]        591,360
#         GELU-21           [[1, 196, 1536]]      [1, 196, 1536]           0
#       Dropout-65          [[1, 196, 384]]       [1, 196, 384]            0
#        Linear-90          [[1, 196, 1536]]      [1, 196, 384]         590,208
#         Mlp-21            [[1, 196, 384]]       [1, 196, 384]            0
# SwinTransformerBlock-21   [[1, 196, 384]]       [1, 196, 384]            0
#      LayerNorm-51         [[1, 196, 384]]       [1, 196, 384]           768
#        Linear-91           [[4, 49, 384]]       [4, 49, 1152]         443,520
#       Softmax-22         [[4, 12, 49, 49]]     [4, 12, 49, 49]           0
#       Dropout-66         [[4, 12, 49, 49]]     [4, 12, 49, 49]           0
#        Linear-92           [[4, 49, 384]]        [4, 49, 384]         147,840
#       Dropout-67           [[4, 49, 384]]        [4, 49, 384]            0
#   WindowAttention-22       [[4, 49, 384]]        [4, 49, 384]          2,028
#       DropPath-20         [[1, 196, 384]]       [1, 196, 384]            0
#      LayerNorm-52         [[1, 196, 384]]       [1, 196, 384]           768
#        Linear-93          [[1, 196, 384]]       [1, 196, 1536]        591,360
#         GELU-22           [[1, 196, 1536]]      [1, 196, 1536]           0
#       Dropout-68          [[1, 196, 384]]       [1, 196, 384]            0
#        Linear-94          [[1, 196, 1536]]      [1, 196, 384]         590,208
#         Mlp-22            [[1, 196, 384]]       [1, 196, 384]            0
# SwinTransformerBlock-22   [[1, 196, 384]]       [1, 196, 384]            0
#      LayerNorm-53         [[1, 49, 1536]]       [1, 49, 1536]          3,072
#        Linear-95          [[1, 49, 1536]]        [1, 49, 768]        1,179,648
#     PatchMerging-6        [[1, 196, 384]]        [1, 49, 768]            0
#      BasicLayer-7         [[1, 196, 384]]        [1, 49, 768]            0
#      LayerNorm-54          [[1, 49, 768]]        [1, 49, 768]          1,536
#        Linear-96           [[1, 49, 768]]       [1, 49, 2304]        1,771,776
#       Softmax-23         [[1, 24, 49, 49]]     [1, 24, 49, 49]           0
#       Dropout-69         [[1, 24, 49, 49]]     [1, 24, 49, 49]           0
#        Linear-97           [[1, 49, 768]]        [1, 49, 768]         590,592
#       Dropout-70           [[1, 49, 768]]        [1, 49, 768]            0
#   WindowAttention-23       [[1, 49, 768]]        [1, 49, 768]          4,056
#       DropPath-21          [[1, 49, 768]]        [1, 49, 768]            0
#      LayerNorm-55          [[1, 49, 768]]        [1, 49, 768]          1,536
#        Linear-98           [[1, 49, 768]]       [1, 49, 3072]        2,362,368
#         GELU-23           [[1, 49, 3072]]       [1, 49, 3072]            0
#       Dropout-71           [[1, 49, 768]]        [1, 49, 768]            0
#        Linear-99          [[1, 49, 3072]]        [1, 49, 768]        2,360,064
#         Mlp-23             [[1, 49, 768]]        [1, 49, 768]            0
# SwinTransformerBlock-23    [[1, 49, 768]]        [1, 49, 768]            0
#      LayerNorm-56          [[1, 49, 768]]        [1, 49, 768]          1,536
#       Linear-100           [[1, 49, 768]]       [1, 49, 2304]        1,771,776
#       Softmax-24         [[1, 24, 49, 49]]     [1, 24, 49, 49]           0
#       Dropout-72         [[1, 24, 49, 49]]     [1, 24, 49, 49]           0
#       Linear-101           [[1, 49, 768]]        [1, 49, 768]         590,592
#       Dropout-73           [[1, 49, 768]]        [1, 49, 768]            0
#   WindowAttention-24       [[1, 49, 768]]        [1, 49, 768]          4,056
#       DropPath-22          [[1, 49, 768]]        [1, 49, 768]            0
#      LayerNorm-57          [[1, 49, 768]]        [1, 49, 768]          1,536
#       Linear-102           [[1, 49, 768]]       [1, 49, 3072]        2,362,368
#         GELU-24           [[1, 49, 3072]]       [1, 49, 3072]            0
#       Dropout-74           [[1, 49, 768]]        [1, 49, 768]            0
#       Linear-103          [[1, 49, 3072]]        [1, 49, 768]        2,360,064
#         Mlp-24             [[1, 49, 768]]        [1, 49, 768]            0
# SwinTransformerBlock-24    [[1, 49, 768]]        [1, 49, 768]            0
#      BasicLayer-8          [[1, 49, 768]]        [1, 49, 768]            0
#      LayerNorm-58          [[1, 49, 768]]        [1, 49, 768]          1,536
#   AdaptiveAvgPool1D-2      [[1, 768, 49]]        [1, 768, 1]             0
#       Linear-104             [[1, 768]]            [1, 10]             7,690
# ===================================================================================
# Total params: 27,527,044
# Trainable params: 27,527,044
# Non-trainable params: 0
# -----------------------------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 282.34
# Params size (MB): 105.01
# Estimated Total Size (MB): 387.92
# -----------------------------------------------------------------------------------
# {'total_params': 27527044, 'trainable_params': 27527044}

# %%
def swin_ti(pretrained=False, **kwargs):
    model = SwinTransformer(**kwargs)
    if pretrained:
        model.set_dict(paddle.load('swin_tiny_patch4_window7_224.pdparams'))
    return model, transforms_224

# %%
def get_transforms(resize, crop):
    transforms = [T.Resize(resize, interpolation='bicubic')]
    if crop:
        transforms.append(T.CenterCrop(crop))
    transforms.append(T.ToTensor())
    transforms.append(T.Normalize(
        mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]))
    transforms = T.Compose(transforms)
    return transforms


transforms_224 = get_transforms(256, 224)
transforms_384 = get_transforms((384, 384), None)

# %%
import os
import cv2
import numpy as np

import paddle

# from ppim import pit_b_distilled
from PIL import Image

# 构建数据集
class ILSVRC2012(paddle.io.Dataset):
    def __init__(self, root, label_list, transform, backend='pil'):
        self.transform = transform
        self.root = root
        self.label_list = label_list
        self.backend = backend
        self.load_datas()

    def load_datas(self):
        self.imgs = []
        self.labels = []
        with open(self.label_list, 'r') as f:
            for line in f:
                img, label = line[:-1].split(' ')
                self.imgs.append(os.path.join(self.root, img))
                self.labels.append(int(label))

    def __getitem__(self, idx):
        label = self.labels[idx]
        image = self.imgs[idx]
        if self.backend=='cv2':
            image = cv2.imread(image)
        else:
            image = Image.open(image).convert('RGB')
        image = self.transform(image)
        return image.astype('float32'), np.array(label).astype('int64')

    def __len__(self):
        return len(self.imgs)



# 配置模型
model, val_transforms = swin_ti(pretrained=True)
model = paddle.Model(model)
model.prepare(metrics=paddle.metric.Accuracy(topk=(1, 5)))

# 配置数据集
val_dataset = ILSVRC2012('data68594', transform=val_transforms, label_list='data68594/val_list.txt')

# 模型验证
model.evaluate(val_dataset, batch_size=8)
# Out:
# Eval begin...
# The loss value printed in the log is the current batch, and the metric is the average value of previous step.
# C:\Users\fzx\.conda\envs\paddle\lib\site-packages\paddle\fluid\layers\utils.py:77: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.10 it will stop working
#   return (isinstance(seq, collections.Sequence) and
# [8, 3136, 96]
# [8, 784, 192]
# [8, 196, 384]
# [8, 49, 768]
# [8, 49, 768]
# [8, 3136, 96]
# [8, 784, 192]
# [8, 196, 384]
# [8, 49, 768]
# [8, 49, 768]
# [8, 3136, 96]
# [8, 784, 192]
# [8, 196, 384]
# [8, 49, 768]
# [8, 49, 768]
# [8, 3136, 96]
# [8, 784, 192]
# [8, 196, 384]
# [8, 49, 768]
# [8, 49, 768]
# [8, 3136, 96]
# [8, 784, 192]
# [8, 196, 384]
# [8, 49, 768]
# [8, 49, 768]
# [8, 3136, 96]
# [8, 784, 192]
# [8, 196, 384]
# [8, 49, 768]
# [8, 49, 768]
# [8, 3136, 96]
# [8, 784, 192]
# [8, 196, 384]
# [8, 49, 768]
# [8, 49, 768]
# [8, 3136, 96]
# [8, 784, 192]
# [8, 196, 384]
# [8, 49, 768]
# [8, 49, 768]
# [8, 3136, 96]
# [8, 784, 192]
# [8, 196, 384]
# [8, 49, 768]
# [8, 49, 768]
# [8, 3136, 96]
# [8, 784, 192]
# [8, 196, 384]
# [8, 49, 768]
# [8, 49, 768]
# step   10/6250 - acc_top1: 0.8250 - acc_top5: 0.9875 - 323ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-d1c4d88f08f1> in <module>
#      50
#      51 # 模型验证
# ---> 52 model.evaluate(val_dataset, batch_size=8)
#
# ~\.conda\envs\paddle\lib\site-packages\paddle\hapi\model.py in evaluate(self, eval_data, batch_size, log_freq, verbose, num_workers, callbacks)
#    1595                        'metrics': self._metrics_name()})
#    1596
# -> 1597         logs = self._run_one_epoch(eval_loader, cbks, 'eval')
#    1598
#    1599         cbks.on_end('eval', logs)
#
# ~\.conda\envs\paddle\lib\site-packages\paddle\hapi\model.py in _run_one_epoch(self, data_loader, callbacks, mode, logs)
#    1777     def _run_one_epoch(self, data_loader, callbacks, mode, logs={}):
#    1778         outputs = []
# -> 1779         for step, data in enumerate(data_loader):
#    1780             # data might come from different types of data_loader and have
#    1781             # different format, as following:
#
# ~\.conda\envs\paddle\lib\site-packages\paddle\fluid\dataloader\dataloader_iter.py in __next__(self)
#     349         try:
#     350             if in_dygraph_mode():
# --> 351                 return self._reader.read_next_var_list()
#     352             else:
#     353                 if self._return_list:
#
# KeyboardInterrupt:

# %%
swin = paddle.load('swin_tiny_patch4_window7_224.pdparams')
model = swin_tiny_window7_224(class_dim = 10)
unet = model.state_dict()
# Out:
# G:\Python\Anaconda3\envs\paddle\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
for ku, ks in zip(uw.keys(), w.keys()):
    print(ku,uw[ku].shape,'####',ks,w[ks].shape)
# Out:
# patch_embed.proj.weight [96, 3, 4, 4] #### patch_embed.proj.weight (96, 3, 4, 4)
# patch_embed.proj.bias [96] #### patch_embed.proj.bias (96,)
# patch_embed.norm.weight [96] #### patch_embed.norm.weight (96,)
# patch_embed.norm.bias [96] #### patch_embed.norm.bias (96,)
# layers.0.blocks.0.norm1.weight [96] #### layers.0.blocks.0.norm1.weight (96,)
# layers.0.blocks.0.norm1.bias [96] #### layers.0.blocks.0.norm1.bias (96,)
# layers.0.blocks.0.attn.relative_position_bias_table [169, 3] #### layers.0.blocks.0.attn.qkv.weight (96, 288)
# layers.0.blocks.0.attn.relative_position_index [49, 49] #### layers.0.blocks.0.attn.qkv.bias (288,)
# layers.0.blocks.0.attn.qkv.weight [96, 288] #### layers.0.blocks.0.attn.proj.weight (96, 96)
# layers.0.blocks.0.attn.qkv.bias [288] #### layers.0.blocks.0.attn.proj.bias (96,)
# layers.0.blocks.0.attn.proj.weight [96, 96] #### layers.0.blocks.0.norm2.weight (96,)
# layers.0.blocks.0.attn.proj.bias [96] #### layers.0.blocks.0.norm2.bias (96,)
# layers.0.blocks.0.norm2.weight [96] #### layers.0.blocks.0.mlp.fc1.weight (96, 384)
# layers.0.blocks.0.norm2.bias [96] #### layers.0.blocks.0.mlp.fc1.bias (384,)
# layers.0.blocks.0.mlp.fc1.weight [96, 384] #### layers.0.blocks.0.mlp.fc2.weight (384, 96)
# layers.0.blocks.0.mlp.fc1.bias [384] #### layers.0.blocks.0.mlp.fc2.bias (96,)
# layers.0.blocks.0.mlp.fc2.weight [384, 96] #### layers.0.blocks.1.norm1.weight (96,)
# layers.0.blocks.0.mlp.fc2.bias [96] #### layers.0.blocks.1.norm1.bias (96,)
# layers.0.blocks.1.attn_mask [64, 49, 49] #### layers.0.blocks.1.attn.qkv.weight (96, 288)
# layers.0.blocks.1.norm1.weight [96] #### layers.0.blocks.1.attn.qkv.bias (288,)
# layers.0.blocks.1.norm1.bias [96] #### layers.0.blocks.1.attn.proj.weight (96, 96)
# layers.0.blocks.1.attn.relative_position_bias_table [169, 3] #### layers.0.blocks.1.attn.proj.bias (96,)
# layers.0.blocks.1.attn.relative_position_index [49, 49] #### layers.0.blocks.1.norm2.weight (96,)
# layers.0.blocks.1.attn.qkv.weight [96, 288] #### layers.0.blocks.1.norm2.bias (96,)
# layers.0.blocks.1.attn.qkv.bias [288] #### layers.0.blocks.1.mlp.fc1.weight (96, 384)
# layers.0.blocks.1.attn.proj.weight [96, 96] #### layers.0.blocks.1.mlp.fc1.bias (384,)
# layers.0.blocks.1.attn.proj.bias [96] #### layers.0.blocks.1.mlp.fc2.weight (384, 96)
# layers.0.blocks.1.norm2.weight [96] #### layers.0.blocks.1.mlp.fc2.bias (96,)
# layers.0.blocks.1.norm2.bias [96] #### layers.0.downsample.norm.weight (384,)
# layers.0.blocks.1.mlp.fc1.weight [96, 384] #### layers.0.downsample.norm.bias (384,)
# layers.0.blocks.1.mlp.fc1.bias [384] #### layers.1.blocks.0.norm1.weight (192,)
# layers.0.blocks.1.mlp.fc2.weight [384, 96] #### layers.1.blocks.0.norm1.bias (192,)
# layers.0.blocks.1.mlp.fc2.bias [96] #### layers.1.blocks.0.attn.qkv.weight (192, 576)
# layers.0.downsample.reduction.weight [384, 192] #### layers.1.blocks.0.attn.qkv.bias (576,)
# layers.0.downsample.norm.weight [384] #### layers.1.blocks.0.attn.proj.weight (192, 192)
# layers.0.downsample.norm.bias [384] #### layers.1.blocks.0.attn.proj.bias (192,)
# layers.1.blocks.0.norm1.weight [192] #### layers.1.blocks.0.norm2.weight (192,)
# layers.1.blocks.0.norm1.bias [192] #### layers.1.blocks.0.norm2.bias (192,)
# layers.1.blocks.0.attn.relative_position_bias_table [169, 6] #### layers.1.blocks.0.mlp.fc1.weight (192, 768)
# layers.1.blocks.0.attn.relative_position_index [49, 49] #### layers.1.blocks.0.mlp.fc1.bias (768,)
# layers.1.blocks.0.attn.qkv.weight [192, 576] #### layers.1.blocks.0.mlp.fc2.weight (768, 192)
# layers.1.blocks.0.attn.qkv.bias [576] #### layers.1.blocks.0.mlp.fc2.bias (192,)
# layers.1.blocks.0.attn.proj.weight [192, 192] #### layers.1.blocks.1.norm1.weight (192,)
# layers.1.blocks.0.attn.proj.bias [192] #### layers.1.blocks.1.norm1.bias (192,)
# layers.1.blocks.0.norm2.weight [192] #### layers.1.blocks.1.attn.qkv.weight (192, 576)
# layers.1.blocks.0.norm2.bias [192] #### layers.1.blocks.1.attn.qkv.bias (576,)
# layers.1.blocks.0.mlp.fc1.weight [192, 768] #### layers.1.blocks.1.attn.proj.weight (192, 192)
# layers.1.blocks.0.mlp.fc1.bias [768] #### layers.1.blocks.1.attn.proj.bias (192,)
# layers.1.blocks.0.mlp.fc2.weight [768, 192] #### layers.1.blocks.1.norm2.weight (192,)
# layers.1.blocks.0.mlp.fc2.bias [192] #### layers.1.blocks.1.norm2.bias (192,)
# layers.1.blocks.1.attn_mask [16, 49, 49] #### layers.1.blocks.1.mlp.fc1.weight (192, 768)
# layers.1.blocks.1.norm1.weight [192] #### layers.1.blocks.1.mlp.fc1.bias (768,)
# layers.1.blocks.1.norm1.bias [192] #### layers.1.blocks.1.mlp.fc2.weight (768, 192)
# layers.1.blocks.1.attn.relative_position_bias_table [169, 6] #### layers.1.blocks.1.mlp.fc2.bias (192,)
# layers.1.blocks.1.attn.relative_position_index [49, 49] #### layers.1.downsample.norm.weight (768,)
# layers.1.blocks.1.attn.qkv.weight [192, 576] #### layers.1.downsample.norm.bias (768,)
# layers.1.blocks.1.attn.qkv.bias [576] #### layers.2.blocks.0.norm1.weight (384,)
# layers.1.blocks.1.attn.proj.weight [192, 192] #### layers.2.blocks.0.norm1.bias (384,)
# layers.1.blocks.1.attn.proj.bias [192] #### layers.2.blocks.0.attn.qkv.weight (384, 1152)
# layers.1.blocks.1.norm2.weight [192] #### layers.2.blocks.0.attn.qkv.bias (1152,)
# layers.1.blocks.1.norm2.bias [192] #### layers.2.blocks.0.attn.proj.weight (384, 384)
# layers.1.blocks.1.mlp.fc1.weight [192, 768] #### layers.2.blocks.0.attn.proj.bias (384,)
# layers.1.blocks.1.mlp.fc1.bias [768] #### layers.2.blocks.0.norm2.weight (384,)
# layers.1.blocks.1.mlp.fc2.weight [768, 192] #### layers.2.blocks.0.norm2.bias (384,)
# layers.1.blocks.1.mlp.fc2.bias [192] #### layers.2.blocks.0.mlp.fc1.weight (384, 1536)
# layers.1.downsample.reduction.weight [768, 384] #### layers.2.blocks.0.mlp.fc1.bias (1536,)
# layers.1.downsample.norm.weight [768] #### layers.2.blocks.0.mlp.fc2.weight (1536, 384)
# layers.1.downsample.norm.bias [768] #### layers.2.blocks.0.mlp.fc2.bias (384,)
# layers.2.blocks.0.norm1.weight [384] #### layers.2.blocks.1.norm1.weight (384,)
# layers.2.blocks.0.norm1.bias [384] #### layers.2.blocks.1.norm1.bias (384,)
# layers.2.blocks.0.attn.relative_position_bias_table [169, 12] #### layers.2.blocks.1.attn.qkv.weight (384, 1152)
# layers.2.blocks.0.attn.relative_position_index [49, 49] #### layers.2.blocks.1.attn.qkv.bias (1152,)
# layers.2.blocks.0.attn.qkv.weight [384, 1152] #### layers.2.blocks.1.attn.proj.weight (384, 384)
# layers.2.blocks.0.attn.qkv.bias [1152] #### layers.2.blocks.1.attn.proj.bias (384,)
# layers.2.blocks.0.attn.proj.weight [384, 384] #### layers.2.blocks.1.norm2.weight (384,)
# layers.2.blocks.0.attn.proj.bias [384] #### layers.2.blocks.1.norm2.bias (384,)
# layers.2.blocks.0.norm2.weight [384] #### layers.2.blocks.1.mlp.fc1.weight (384, 1536)
# layers.2.blocks.0.norm2.bias [384] #### layers.2.blocks.1.mlp.fc1.bias (1536,)
# layers.2.blocks.0.mlp.fc1.weight [384, 1536] #### layers.2.blocks.1.mlp.fc2.weight (1536, 384)
# layers.2.blocks.0.mlp.fc1.bias [1536] #### layers.2.blocks.1.mlp.fc2.bias (384,)
# layers.2.blocks.0.mlp.fc2.weight [1536, 384] #### layers.2.blocks.2.norm1.weight (384,)
# layers.2.blocks.0.mlp.fc2.bias [384] #### layers.2.blocks.2.norm1.bias (384,)
# layers.2.blocks.1.attn_mask [4, 49, 49] #### layers.2.blocks.2.attn.qkv.weight (384, 1152)
# layers.2.blocks.1.norm1.weight [384] #### layers.2.blocks.2.attn.qkv.bias (1152,)
# layers.2.blocks.1.norm1.bias [384] #### layers.2.blocks.2.attn.proj.weight (384, 384)
# layers.2.blocks.1.attn.relative_position_bias_table [169, 12] #### layers.2.blocks.2.attn.proj.bias (384,)
# layers.2.blocks.1.attn.relative_position_index [49, 49] #### layers.2.blocks.2.norm2.weight (384,)
# layers.2.blocks.1.attn.qkv.weight [384, 1152] #### layers.2.blocks.2.norm2.bias (384,)
# layers.2.blocks.1.attn.qkv.bias [1152] #### layers.2.blocks.2.mlp.fc1.weight (384, 1536)
# layers.2.blocks.1.attn.proj.weight [384, 384] #### layers.2.blocks.2.mlp.fc1.bias (1536,)
# layers.2.blocks.1.attn.proj.bias [384] #### layers.2.blocks.2.mlp.fc2.weight (1536, 384)
# layers.2.blocks.1.norm2.weight [384] #### layers.2.blocks.2.mlp.fc2.bias (384,)
# layers.2.blocks.1.norm2.bias [384] #### layers.2.blocks.3.norm1.weight (384,)
# layers.2.blocks.1.mlp.fc1.weight [384, 1536] #### layers.2.blocks.3.norm1.bias (384,)
# layers.2.blocks.1.mlp.fc1.bias [1536] #### layers.2.blocks.3.attn.qkv.weight (384, 1152)
# layers.2.blocks.1.mlp.fc2.weight [1536, 384] #### layers.2.blocks.3.attn.qkv.bias (1152,)
# layers.2.blocks.1.mlp.fc2.bias [384] #### layers.2.blocks.3.attn.proj.weight (384, 384)
# layers.2.blocks.2.norm1.weight [384] #### layers.2.blocks.3.attn.proj.bias (384,)
# layers.2.blocks.2.norm1.bias [384] #### layers.2.blocks.3.norm2.weight (384,)
# layers.2.blocks.2.attn.relative_position_bias_table [169, 12] #### layers.2.blocks.3.norm2.bias (384,)
# layers.2.blocks.2.attn.relative_position_index [49, 49] #### layers.2.blocks.3.mlp.fc1.weight (384, 1536)
# layers.2.blocks.2.attn.qkv.weight [384, 1152] #### layers.2.blocks.3.mlp.fc1.bias (1536,)
# layers.2.blocks.2.attn.qkv.bias [1152] #### layers.2.blocks.3.mlp.fc2.weight (1536, 384)
# layers.2.blocks.2.attn.proj.weight [384, 384] #### layers.2.blocks.3.mlp.fc2.bias (384,)
# layers.2.blocks.2.attn.proj.bias [384] #### layers.2.blocks.4.norm1.weight (384,)
# layers.2.blocks.2.norm2.weight [384] #### layers.2.blocks.4.norm1.bias (384,)
# layers.2.blocks.2.norm2.bias [384] #### layers.2.blocks.4.attn.qkv.weight (384, 1152)
# layers.2.blocks.2.mlp.fc1.weight [384, 1536] #### layers.2.blocks.4.attn.qkv.bias (1152,)
# layers.2.blocks.2.mlp.fc1.bias [1536] #### layers.2.blocks.4.attn.proj.weight (384, 384)
# layers.2.blocks.2.mlp.fc2.weight [1536, 384] #### layers.2.blocks.4.attn.proj.bias (384,)
# layers.2.blocks.2.mlp.fc2.bias [384] #### layers.2.blocks.4.norm2.weight (384,)
# layers.2.blocks.3.attn_mask [4, 49, 49] #### layers.2.blocks.4.norm2.bias (384,)
# layers.2.blocks.3.norm1.weight [384] #### layers.2.blocks.4.mlp.fc1.weight (384, 1536)
# layers.2.blocks.3.norm1.bias [384] #### layers.2.blocks.4.mlp.fc1.bias (1536,)
# layers.2.blocks.3.attn.relative_position_bias_table [169, 12] #### layers.2.blocks.4.mlp.fc2.weight (1536, 384)
# layers.2.blocks.3.attn.relative_position_index [49, 49] #### layers.2.blocks.4.mlp.fc2.bias (384,)
# layers.2.blocks.3.attn.qkv.weight [384, 1152] #### layers.2.blocks.5.norm1.weight (384,)
# layers.2.blocks.3.attn.qkv.bias [1152] #### layers.2.blocks.5.norm1.bias (384,)
# layers.2.blocks.3.attn.proj.weight [384, 384] #### layers.2.blocks.5.attn.qkv.weight (384, 1152)
# layers.2.blocks.3.attn.proj.bias [384] #### layers.2.blocks.5.attn.qkv.bias (1152,)
# layers.2.blocks.3.norm2.weight [384] #### layers.2.blocks.5.attn.proj.weight (384, 384)
# layers.2.blocks.3.norm2.bias [384] #### layers.2.blocks.5.attn.proj.bias (384,)
# layers.2.blocks.3.mlp.fc1.weight [384, 1536] #### layers.2.blocks.5.norm2.weight (384,)
# layers.2.blocks.3.mlp.fc1.bias [1536] #### layers.2.blocks.5.norm2.bias (384,)
# layers.2.blocks.3.mlp.fc2.weight [1536, 384] #### layers.2.blocks.5.mlp.fc1.weight (384, 1536)
# layers.2.blocks.3.mlp.fc2.bias [384] #### layers.2.blocks.5.mlp.fc1.bias (1536,)
# layers.2.blocks.4.norm1.weight [384] #### layers.2.blocks.5.mlp.fc2.weight (1536, 384)
# layers.2.blocks.4.norm1.bias [384] #### layers.2.blocks.5.mlp.fc2.bias (384,)
# layers.2.blocks.4.attn.relative_position_bias_table [169, 12] #### layers.2.downsample.norm.weight (1536,)
# layers.2.blocks.4.attn.relative_position_index [49, 49] #### layers.2.downsample.norm.bias (1536,)
# layers.2.blocks.4.attn.qkv.weight [384, 1152] #### layers.3.blocks.0.norm1.weight (768,)
# layers.2.blocks.4.attn.qkv.bias [1152] #### layers.3.blocks.0.norm1.bias (768,)
# layers.2.blocks.4.attn.proj.weight [384, 384] #### layers.3.blocks.0.attn.qkv.weight (768, 2304)
# layers.2.blocks.4.attn.proj.bias [384] #### layers.3.blocks.0.attn.qkv.bias (2304,)
# layers.2.blocks.4.norm2.weight [384] #### layers.3.blocks.0.attn.proj.weight (768, 768)
# layers.2.blocks.4.norm2.bias [384] #### layers.3.blocks.0.attn.proj.bias (768,)
# layers.2.blocks.4.mlp.fc1.weight [384, 1536] #### layers.3.blocks.0.norm2.weight (768,)
# layers.2.blocks.4.mlp.fc1.bias [1536] #### layers.3.blocks.0.norm2.bias (768,)
# layers.2.blocks.4.mlp.fc2.weight [1536, 384] #### layers.3.blocks.0.mlp.fc1.weight (768, 3072)
# layers.2.blocks.4.mlp.fc2.bias [384] #### layers.3.blocks.0.mlp.fc1.bias (3072,)
# layers.2.blocks.5.attn_mask [4, 49, 49] #### layers.3.blocks.0.mlp.fc2.weight (3072, 768)
# layers.2.blocks.5.norm1.weight [384] #### layers.3.blocks.0.mlp.fc2.bias (768,)
# layers.2.blocks.5.norm1.bias [384] #### layers.3.blocks.1.norm1.weight (768,)
# layers.2.blocks.5.attn.relative_position_bias_table [169, 12] #### layers.3.blocks.1.norm1.bias (768,)
# layers.2.blocks.5.attn.relative_position_index [49, 49] #### layers.3.blocks.1.attn.qkv.weight (768, 2304)
# layers.2.blocks.5.attn.qkv.weight [384, 1152] #### layers.3.blocks.1.attn.qkv.bias (2304,)
# layers.2.blocks.5.attn.qkv.bias [1152] #### layers.3.blocks.1.attn.proj.weight (768, 768)
# layers.2.blocks.5.attn.proj.weight [384, 384] #### layers.3.blocks.1.attn.proj.bias (768,)
# layers.2.blocks.5.attn.proj.bias [384] #### layers.3.blocks.1.norm2.weight (768,)
# layers.2.blocks.5.norm2.weight [384] #### layers.3.blocks.1.norm2.bias (768,)
# layers.2.blocks.5.norm2.bias [384] #### layers.3.blocks.1.mlp.fc1.weight (768, 3072)
# layers.2.blocks.5.mlp.fc1.weight [384, 1536] #### layers.3.blocks.1.mlp.fc1.bias (3072,)
# layers.2.blocks.5.mlp.fc1.bias [1536] #### layers.3.blocks.1.mlp.fc2.weight (3072, 768)
# layers.2.blocks.5.mlp.fc2.weight [1536, 384] #### layers.3.blocks.1.mlp.fc2.bias (768,)
# layers.2.blocks.5.mlp.fc2.bias [384] #### norm.weight (768,)
# layers.2.downsample.reduction.weight [1536, 768] #### norm.bias (768,)
# layers.2.downsample.norm.weight [1536] #### head.weight (768, 1000)
# layers.2.downsample.norm.bias [1536] #### head.bias (1000,)
# layers.3.blocks.0.norm1.weight [768] #### layers.0.blocks.0.attn.relative_position_index (49, 49)
# layers.3.blocks.0.norm1.bias [768] #### layers.0.blocks.1.attn.relative_position_index (49, 49)
# layers.3.blocks.0.attn.relative_position_bias_table [169, 24] #### layers.1.blocks.0.attn.relative_position_index (49, 49)
# layers.3.blocks.0.attn.relative_position_index [49, 49] #### layers.1.blocks.1.attn.relative_position_index (49, 49)
# layers.3.blocks.0.attn.qkv.weight [768, 2304] #### layers.2.blocks.0.attn.relative_position_index (49, 49)
# layers.3.blocks.0.attn.qkv.bias [2304] #### layers.2.blocks.1.attn.relative_position_index (49, 49)
# layers.3.blocks.0.attn.proj.weight [768, 768] #### layers.2.blocks.2.attn.relative_position_index (49, 49)
# layers.3.blocks.0.attn.proj.bias [768] #### layers.2.blocks.3.attn.relative_position_index (49, 49)
# layers.3.blocks.0.norm2.weight [768] #### layers.2.blocks.4.attn.relative_position_index (49, 49)
# layers.3.blocks.0.norm2.bias [768] #### layers.2.blocks.5.attn.relative_position_index (49, 49)
# layers.3.blocks.0.mlp.fc1.weight [768, 3072] #### layers.3.blocks.0.attn.relative_position_index (49, 49)
# layers.3.blocks.0.mlp.fc1.bias [3072] #### layers.3.blocks.1.attn.relative_position_index (49, 49)
# layers.3.blocks.0.mlp.fc2.weight [3072, 768] #### layers.0.blocks.1.attn_mask (64, 49, 49)
# layers.3.blocks.0.mlp.fc2.bias [768] #### layers.1.blocks.1.attn_mask (16, 49, 49)
# layers.3.blocks.1.norm1.weight [768] #### layers.2.blocks.1.attn_mask (4, 49, 49)
# layers.3.blocks.1.norm1.bias [768] #### layers.2.blocks.3.attn_mask (4, 49, 49)
# layers.3.blocks.1.attn.relative_position_bias_table [169, 24] #### layers.2.blocks.5.attn_mask (4, 49, 49)
# layers.3.blocks.1.attn.relative_position_index [49, 49] #### layers.0.blocks.0.attn.relative_position_bias_table (169, 3)
# layers.3.blocks.1.attn.qkv.weight [768, 2304] #### layers.0.blocks.1.attn.relative_position_bias_table (169, 3)
# layers.3.blocks.1.attn.qkv.bias [2304] #### layers.1.blocks.0.attn.relative_position_bias_table (169, 6)
# layers.3.blocks.1.attn.proj.weight [768, 768] #### layers.1.blocks.1.attn.relative_position_bias_table (169, 6)
# layers.3.blocks.1.attn.proj.bias [768] #### layers.2.blocks.0.attn.relative_position_bias_table (169, 12)
# layers.3.blocks.1.norm2.weight [768] #### layers.2.blocks.1.attn.relative_position_bias_table (169, 12)
# layers.3.blocks.1.norm2.bias [768] #### layers.2.blocks.2.attn.relative_position_bias_table (169, 12)
# layers.3.blocks.1.mlp.fc1.weight [768, 3072] #### layers.2.blocks.3.attn.relative_position_bias_table (169, 12)
# layers.3.blocks.1.mlp.fc1.bias [3072] #### layers.2.blocks.4.attn.relative_position_bias_table (169, 12)
# layers.3.blocks.1.mlp.fc2.weight [3072, 768] #### layers.2.blocks.5.attn.relative_position_bias_table (169, 12)
# layers.3.blocks.1.mlp.fc2.bias [768] #### layers.3.blocks.0.attn.relative_position_bias_table (169, 24)
# norm.weight [768] #### layers.3.blocks.1.attn.relative_position_bias_table (169, 24)
# norm.bias [768] #### layers.0.downsample.reduction.weight (384, 192)
# head.weight [768, 10] #### layers.1.downsample.reduction.weight (768, 384)
# head.bias [10] #### layers.2.downsample.reduction.weight (1536, 768)

# %%
for kunet in unet.keys():
    print(kunet,unet[kunet].shape)
# Out:
# patch_embed.proj.weight [96, 3, 4, 4]
# patch_embed.proj.bias [96]
# patch_embed.norm.weight [96]
# patch_embed.norm.bias [96]
# layers.0.blocks.0.norm1.weight [96]
# layers.0.blocks.0.norm1.bias [96]
# layers.0.blocks.0.attn.relative_position_bias_table [169, 3]
# layers.0.blocks.0.attn.relative_position_index [49, 49]
# layers.0.blocks.0.attn.qkv.weight [96, 288]
# layers.0.blocks.0.attn.qkv.bias [288]
# layers.0.blocks.0.attn.proj.weight [96, 96]
# layers.0.blocks.0.attn.proj.bias [96]
# layers.0.blocks.0.norm2.weight [96]
# layers.0.blocks.0.norm2.bias [96]
# layers.0.blocks.0.mlp.fc1.weight [96, 384]
# layers.0.blocks.0.mlp.fc1.bias [384]
# layers.0.blocks.0.mlp.fc2.weight [384, 96]
# layers.0.blocks.0.mlp.fc2.bias [96]
# layers.0.blocks.1.attn_mask [64, 49, 49]
# layers.0.blocks.1.norm1.weight [96]
# layers.0.blocks.1.norm1.bias [96]
# layers.0.blocks.1.attn.relative_position_bias_table [169, 3]
# layers.0.blocks.1.attn.relative_position_index [49, 49]
# layers.0.blocks.1.attn.qkv.weight [96, 288]
# layers.0.blocks.1.attn.qkv.bias [288]
# layers.0.blocks.1.attn.proj.weight [96, 96]
# layers.0.blocks.1.attn.proj.bias [96]
# layers.0.blocks.1.norm2.weight [96]
# layers.0.blocks.1.norm2.bias [96]
# layers.0.blocks.1.mlp.fc1.weight [96, 384]
# layers.0.blocks.1.mlp.fc1.bias [384]
# layers.0.blocks.1.mlp.fc2.weight [384, 96]
# layers.0.blocks.1.mlp.fc2.bias [96]
# layers.0.downsample.reduction.weight [384, 192]
# layers.0.downsample.norm.weight [384]
# layers.0.downsample.norm.bias [384]
# layers.1.blocks.0.norm1.weight [192]
# layers.1.blocks.0.norm1.bias [192]
# layers.1.blocks.0.attn.relative_position_bias_table [169, 6]
# layers.1.blocks.0.attn.relative_position_index [49, 49]
# layers.1.blocks.0.attn.qkv.weight [192, 576]
# layers.1.blocks.0.attn.qkv.bias [576]
# layers.1.blocks.0.attn.proj.weight [192, 192]
# layers.1.blocks.0.attn.proj.bias [192]
# layers.1.blocks.0.norm2.weight [192]
# layers.1.blocks.0.norm2.bias [192]
# layers.1.blocks.0.mlp.fc1.weight [192, 768]
# layers.1.blocks.0.mlp.fc1.bias [768]
# layers.1.blocks.0.mlp.fc2.weight [768, 192]
# layers.1.blocks.0.mlp.fc2.bias [192]
# layers.1.blocks.1.attn_mask [16, 49, 49]
# layers.1.blocks.1.norm1.weight [192]
# layers.1.blocks.1.norm1.bias [192]
# layers.1.blocks.1.attn.relative_position_bias_table [169, 6]
# layers.1.blocks.1.attn.relative_position_index [49, 49]
# layers.1.blocks.1.attn.qkv.weight [192, 576]
# layers.1.blocks.1.attn.qkv.bias [576]
# layers.1.blocks.1.attn.proj.weight [192, 192]
# layers.1.blocks.1.attn.proj.bias [192]
# layers.1.blocks.1.norm2.weight [192]
# layers.1.blocks.1.norm2.bias [192]
# layers.1.blocks.1.mlp.fc1.weight [192, 768]
# layers.1.blocks.1.mlp.fc1.bias [768]
# layers.1.blocks.1.mlp.fc2.weight [768, 192]
# layers.1.blocks.1.mlp.fc2.bias [192]
# layers.1.downsample.reduction.weight [768, 384]
# layers.1.downsample.norm.weight [768]
# layers.1.downsample.norm.bias [768]
# layers.2.blocks.0.norm1.weight [384]
# layers.2.blocks.0.norm1.bias [384]
# layers.2.blocks.0.attn.relative_position_bias_table [169, 12]
# layers.2.blocks.0.attn.relative_position_index [49, 49]
# layers.2.blocks.0.attn.qkv.weight [384, 1152]
# layers.2.blocks.0.attn.qkv.bias [1152]
# layers.2.blocks.0.attn.proj.weight [384, 384]
# layers.2.blocks.0.attn.proj.bias [384]
# layers.2.blocks.0.norm2.weight [384]
# layers.2.blocks.0.norm2.bias [384]
# layers.2.blocks.0.mlp.fc1.weight [384, 1536]
# layers.2.blocks.0.mlp.fc1.bias [1536]
# layers.2.blocks.0.mlp.fc2.weight [1536, 384]
# layers.2.blocks.0.mlp.fc2.bias [384]
# layers.2.blocks.1.attn_mask [4, 49, 49]
# layers.2.blocks.1.norm1.weight [384]
# layers.2.blocks.1.norm1.bias [384]
# layers.2.blocks.1.attn.relative_position_bias_table [169, 12]
# layers.2.blocks.1.attn.relative_position_index [49, 49]
# layers.2.blocks.1.attn.qkv.weight [384, 1152]
# layers.2.blocks.1.attn.qkv.bias [1152]
# layers.2.blocks.1.attn.proj.weight [384, 384]
# layers.2.blocks.1.attn.proj.bias [384]
# layers.2.blocks.1.norm2.weight [384]
# layers.2.blocks.1.norm2.bias [384]
# layers.2.blocks.1.mlp.fc1.weight [384, 1536]
# layers.2.blocks.1.mlp.fc1.bias [1536]
# layers.2.blocks.1.mlp.fc2.weight [1536, 384]
# layers.2.blocks.1.mlp.fc2.bias [384]
# layers.2.blocks.2.norm1.weight [384]
# layers.2.blocks.2.norm1.bias [384]
# layers.2.blocks.2.attn.relative_position_bias_table [169, 12]
# layers.2.blocks.2.attn.relative_position_index [49, 49]
# layers.2.blocks.2.attn.qkv.weight [384, 1152]
# layers.2.blocks.2.attn.qkv.bias [1152]
# layers.2.blocks.2.attn.proj.weight [384, 384]
# layers.2.blocks.2.attn.proj.bias [384]
# layers.2.blocks.2.norm2.weight [384]
# layers.2.blocks.2.norm2.bias [384]
# layers.2.blocks.2.mlp.fc1.weight [384, 1536]
# layers.2.blocks.2.mlp.fc1.bias [1536]
# layers.2.blocks.2.mlp.fc2.weight [1536, 384]
# layers.2.blocks.2.mlp.fc2.bias [384]
# layers.2.blocks.3.attn_mask [4, 49, 49]
# layers.2.blocks.3.norm1.weight [384]
# layers.2.blocks.3.norm1.bias [384]
# layers.2.blocks.3.attn.relative_position_bias_table [169, 12]
# layers.2.blocks.3.attn.relative_position_index [49, 49]
# layers.2.blocks.3.attn.qkv.weight [384, 1152]
# layers.2.blocks.3.attn.qkv.bias [1152]
# layers.2.blocks.3.attn.proj.weight [384, 384]
# layers.2.blocks.3.attn.proj.bias [384]
# layers.2.blocks.3.norm2.weight [384]
# layers.2.blocks.3.norm2.bias [384]
# layers.2.blocks.3.mlp.fc1.weight [384, 1536]
# layers.2.blocks.3.mlp.fc1.bias [1536]
# layers.2.blocks.3.mlp.fc2.weight [1536, 384]
# layers.2.blocks.3.mlp.fc2.bias [384]
# layers.2.blocks.4.norm1.weight [384]
# layers.2.blocks.4.norm1.bias [384]
# layers.2.blocks.4.attn.relative_position_bias_table [169, 12]
# layers.2.blocks.4.attn.relative_position_index [49, 49]
# layers.2.blocks.4.attn.qkv.weight [384, 1152]
# layers.2.blocks.4.attn.qkv.bias [1152]
# layers.2.blocks.4.attn.proj.weight [384, 384]
# layers.2.blocks.4.attn.proj.bias [384]
# layers.2.blocks.4.norm2.weight [384]
# layers.2.blocks.4.norm2.bias [384]
# layers.2.blocks.4.mlp.fc1.weight [384, 1536]
# layers.2.blocks.4.mlp.fc1.bias [1536]
# layers.2.blocks.4.mlp.fc2.weight [1536, 384]
# layers.2.blocks.4.mlp.fc2.bias [384]
# layers.2.blocks.5.attn_mask [4, 49, 49]
# layers.2.blocks.5.norm1.weight [384]
# layers.2.blocks.5.norm1.bias [384]
# layers.2.blocks.5.attn.relative_position_bias_table [169, 12]
# layers.2.blocks.5.attn.relative_position_index [49, 49]
# layers.2.blocks.5.attn.qkv.weight [384, 1152]
# layers.2.blocks.5.attn.qkv.bias [1152]
# layers.2.blocks.5.attn.proj.weight [384, 384]
# layers.2.blocks.5.attn.proj.bias [384]
# layers.2.blocks.5.norm2.weight [384]
# layers.2.blocks.5.norm2.bias [384]
# layers.2.blocks.5.mlp.fc1.weight [384, 1536]
# layers.2.blocks.5.mlp.fc1.bias [1536]
# layers.2.blocks.5.mlp.fc2.weight [1536, 384]
# layers.2.blocks.5.mlp.fc2.bias [384]
# layers.2.downsample.reduction.weight [1536, 768]
# layers.2.downsample.norm.weight [1536]
# layers.2.downsample.norm.bias [1536]
# layers.3.blocks.0.norm1.weight [768]
# layers.3.blocks.0.norm1.bias [768]
# layers.3.blocks.0.attn.relative_position_bias_table [169, 24]
# layers.3.blocks.0.attn.relative_position_index [49, 49]
# layers.3.blocks.0.attn.qkv.weight [768, 2304]
# layers.3.blocks.0.attn.qkv.bias [2304]
# layers.3.blocks.0.attn.proj.weight [768, 768]
# layers.3.blocks.0.attn.proj.bias [768]
# layers.3.blocks.0.norm2.weight [768]
# layers.3.blocks.0.norm2.bias [768]
# layers.3.blocks.0.mlp.fc1.weight [768, 3072]
# layers.3.blocks.0.mlp.fc1.bias [3072]
# layers.3.blocks.0.mlp.fc2.weight [3072, 768]
# layers.3.blocks.0.mlp.fc2.bias [768]
# layers.3.blocks.1.norm1.weight [768]
# layers.3.blocks.1.norm1.bias [768]
# layers.3.blocks.1.attn.relative_position_bias_table [169, 24]
# layers.3.blocks.1.attn.relative_position_index [49, 49]
# layers.3.blocks.1.attn.qkv.weight [768, 2304]
# layers.3.blocks.1.attn.qkv.bias [2304]
# layers.3.blocks.1.attn.proj.weight [768, 768]
# layers.3.blocks.1.attn.proj.bias [768]
# layers.3.blocks.1.norm2.weight [768]
# layers.3.blocks.1.norm2.bias [768]
# layers.3.blocks.1.mlp.fc1.weight [768, 3072]
# layers.3.blocks.1.mlp.fc1.bias [3072]
# layers.3.blocks.1.mlp.fc2.weight [3072, 768]
# layers.3.blocks.1.mlp.fc2.bias [768]
# norm.weight [768]
# norm.bias [768]
# head.weight [768, 10]
# head.bias [10]
